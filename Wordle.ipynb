# %%
import re
import pandas as pd

# %%
df = pd.read_csv("unigram_freq.csv", header=None, delimiter=",")

# %%
df
# Out:
#               0            1
# 0          word        count
# 1           the  23135851162
# 2            of  13151942776
# 3           and  12997637966
# 4            to  12136980858
# ...         ...          ...
# 333329    gooek        12711
# 333330   gooddg        12711
# 333331  gooblle        12711
# 333332   gollgo        12711
# 333333    golgw        12711
#
# [333334 rows x 2 columns]

# %%
df2 = [df[0][x] for x in range(len(df[0])) if len(str(df[0][x])) == 5]

# %%
search_regex = r"[a-z][a-z][t][a-z][e]"

# %%
possibilities = []

# %%
for x in df2:
    check = re.fullmatch(search_regex, x)
    if check:
        possibilities.append(check.group())

# %%
possibilities
# Out:
# ['title',
#  'katie',
#  'notre',
#  'cutie',
#  'matte',
#  'butte',
#  'metre',
#  'litre',
#  'entre',
#  'cette',
#  'vitae',
#  'votre',
#  'ofthe',
#  'estee',
#  'lathe',
#  'bitte',
#  'bette',
#  'autre',
#  'latte',
#  'mitre',
#  'titre',
#  'inthe',
#  'bathe',
#  'tutte',
#  'witte',
#  'artie',
#  'motte',
#  'tithe',
#  'fotze',
#  'dette',
#  'fette',
#  'tothe',
#  'bythe',
#  'lytle',
#  'altre',
#  'vette',
#  'nutte',
#  'lotte',
#  'litle',
#  'antje',
#  'notte',
#  'hythe',
#  'mitte',
#  'onthe',
#  'hatte',
#  'wythe',
#  'satie',
#  'untie',
#  'sette',
#  'lutte',
#  'catie',
#  'mette',
#  'bethe',
#  'lithe',
#  'hotle',
#  'pitre',
#  'nette',
#  'outre',
#  'petre',
#  'mathe',
#  'setae',
#  'votze',
#  'astle',
#  'kathe',
#  'atthe',
#  'jette',
#  'pathe',
#  'oltre',
#  'tette',
#  'litte',
#  'kutje',
#  'natpe',
#  'bothe',
#  'isthe',
#  'katze',
#  'kette',
#  'rothe',
#  'withe',
#  'nitte',
#  'motle',
#  'titte',
#  'batte',
#  'ifthe',
# ...
